# %% [markdown]
# <a href="https://colab.research.google.com/github/brownnyi/E-commerce_data-analyst/blob/main/%EC%A7%80%EB%8F%84%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
users = pd.read_csv('users.csv')

# %%
users
# Out:
#           id first_name last_name                      email  age gender  \
# 0       4473      Julie      Cruz      juliecruz@example.org   23      F
# 1       6971     Kendra     Smith    kendrasmith@example.net   56      F
# 2       7701      Jason     White     jasonwhite@example.net   62      M
# 3      16347    Kathryn    Thomas  kathrynthomas@example.net   16      F
# 4      33941      Shane      Cook      shanecook@example.net   58      M
# ...      ...        ...       ...                        ...  ...    ...
# 99995     78      Sonya   Cameron   sonyacameron@example.org   19      F
# 99996  14033    Kenneth     Lewis   kennethlewis@example.net   52      M
# 99997  43268     Pamela      Kirk     pamelakirk@example.net   43      F
# 99998  70954       Anna     Davis      annadavis@example.com   50      F
# 99999  77749       Tara   Kennedy    tarakennedy@example.com   68      F
#
#                state                 street_address postal_code  \
# ...

# %% [markdown]
# - folium
# - leaflet.js 기반으로 만들어진 라이브러리
# - 지도위에 경도, 위도 데이터를 활용해 표현하는 지도 시각화 라이브러리

# %%
location_data = users[['id','latitude','longitude']]

# %%
using_data = users[users['country'] == 'South Korea'][['latitude','longitude']].drop_duplicates()

# %%
len(using_data)
# Out:
# 1382

# %%
#지도 띄우기, 부산 중심

map = folium.Map(location = [35.1796, 129.0756], zoom_start = 11)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i, j in using_data.values[:1383]:
    popup = folium.Popup('1', max_width = 200)
    folium.Marker(location = [i, j] , popup = popup).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
